# %%
import os
import numpy as np
import pandas as pd
import h5py 

import matplotlib.pyplot as plt
# %matplotlib inline
# %load_ext autoreload

# %%
ophys_session_dir = r"\\allen\programs\braintv\production\neuralcoding\prod0\specimen_599659785\ophys_session_639001089"
mouse_id = 334310

# %%
analysis_dir = r'\\allen\programs\braintv\workgroups\nc-ophys\BehaviorImaging\DoC\2P6_data_analysis'

# %%
from visual_behavior_ophys.dataset.visual_behavior_scientifica_dataset import VisualBehaviorScientificaDataset

# %%
dataset= VisualBehaviorScientificaDataset(ophys_session_dir, mouse_id=mouse_id, analysis_dir=analysis_dir)
# Out:
# Visual frames detected in sync: 215789
# 2P frames detected in sync: 111670
# 170927
# visual frames in pkl file: 215789
# Loading \\allen\programs\braintv\workgroups\neuralcoding\Behavior\Data\M334310\output\170927150910-task=DoC_NaturalImages_Ophys_SessionA_stage=natural_images_ophys_sessionA_mouse=M334310.pkl
# stim type is  images
# c:\users\marinag\documents\code\visual_behavior_ophys\visual_behavior_ophys\dataset\visual_behavior_scientifica_dataset.py:190: FutureWarning: pd.rolling_mean is deprecated for ndarrays and will be removed in a future version
#   running_speed_cm_per_sec = pd.rolling_mean(running_speed_cm_per_sec, window=6)
# length of traces: 111668
# number of segmented cells: 90

# %%
from visual_behavior_ophys.response_analysis.response_analysis import ResponseAnalysis

# %%
ra = ResponseAnalysis(dataset)
# Out:
# length of traces: 111668
# number of segmented cells: 90
# loading response dataframe
# creating mean response dataframe
# c:\users\marinag\documents\code\visual_behavior_ophys\visual_behavior_ophys\response_analysis\response_analysis.py:175: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   (_, p) = stats.f_oneway(trace[baseline_start:baseline_end], trace[stim_start:stim_end])
# creating cell summary dataframe

# %% [markdown]
# ## figure generation code

# %%
from visual_behavior_ophys.plotting_tools import summary_figures as sf
from visual_behavior_ophys.plotting_tools import basic_plotting as bp
from visual_behavior_ophys.roi_mask_analysis import roi_mask_analysis as rm

# %%
rdf = ra.response_df
mdf = ra.mean_response_df
sdf = ra.get_cell_summary_df(p_val_thresh=0.005, sd_over_baseline_thresh=3)
# Out:
# creating cell summary dataframe

# %%
sf.plot_images(dataset,mdf,save=True);

# %%
# sf.plot_experiment_summary_figure(dataset, mdf, sdf, save=True)

# %%
# sf.plot_behavior_events_trace(dataset, ra.response_df.cell.unique(), xmin=360, length=5, ax=None, save=True)

# %%
# sf.plot_traces_heatmap(dataset, save=True,cbar=True,ax=None)

# %%
# for cell in mdf.cell.unique():
#     sf.plot_transition_type_heatmap(ra, [cell], vmax=np.percentile(dataset.dff_traces[cell, :], 99.9), ax=None, cmap='magma', colorbar=False,save=True);

# %%
# for trace in dataset.dff_traces
# sf.plot_trace(timestamps, trace, ax=None, xlabel='seconds', ylabel='dF/F')

# %%
# ra.cell_summary_df = sdf

# %%
sf.plot_cell_summary_figure(dataset,ra, 19, save=False)
# Out:
# c:\users\marinag\documents\code\visual_behavior_ophys\visual_behavior_ophys\plotting_tools\summary_figures.py:1559: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   trace = tdf.mean_trace.values[0][frames_range[0]:frames_range[1]]
# c:\users\marinag\documents\code\visual_behavior_ophys\visual_behavior_ophys\plotting_tools\summary_figures.py:1560: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   sem = tdf.sem_trace.values[0][frames_range[0]:frames_range[1]]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-57b36ca17fc6> in <module>()
# ----> 1 sf.plot_cell_summary_figure(dataset,ra, 19, save=False)
#
# c:\users\marinag\documents\code\visual_behavior_ophys\visual_behavior_ophys\plotting_tools\summary_figures.py in plot_cell_summary_figure(dataset, ra, cell, save)
#    2756     ax = placeAxesOnGrid(fig, dim=(1, 1), xspan=(.7, 0.88), yspan=(.0, .2))
#    2757     ax = plot_trial_types_selectivity_pref_image(ra, [cell], ['HIT', 'MISS'], window=[-2, 3], save=False,
# -> 2758                                                  ax=ax)
#    2759     ax = placeAxesOnGrid(fig, dim=(1, 1), xspan=(.7, 0.88), yspan=(.2, .4))
#    2760     ax = plot_trial_types_selectivity_pref_image(ra, [cell], ['FA', 'CR'], window=[-2, 3], save=False,
#
# c:\users\marinag\documents\code\visual_behavior_ophys\visual_behavior_ophys\plotting_tools\summary_figures.py in plot_trial_types_selectivity_pref_image(ra, cell_list, response_types, window, save, ax)
#    1593     mdf = ra.mean_response_df
#    1594     sdf = ra.cell_summary_df
# -> 1595     colors = sf.get_colors_for_response_types(['CR', 'FA'])
#    1596     frames_range = [(window[0] + ra.response_window[1]) * 30, (window[1] + ra.response_window[1]) * 30]
#    1597     xlabels = np.arange((window[0]), (window[1]) + 1, 1)
#
# NameError: global name 'sf' is not defined
