# %%
import h5py 
import numpy as np
import pandas as pd

# %%
dff_traces_filepath = r"\\allen\programs\braintv\production\neuralcoding\prod0\specimen_594684843\ophys_session_613911974\ophys_experiment_613973387\613973387_dff.h5"

# %%
f = h5py.File(dff_traces_filepath)
f.keys()
# Out:
# [u'data']

# %%
pd.DataFrame(np.asarray(f['data']))
# Out:
#       0         1         2         3         4         5         6       \
# 0   0.043182  0.054291 -0.026250  0.079147  0.055569  0.044834  0.119075
# 1   0.002585 -0.025129 -0.087497 -0.019076 -0.095821  0.038438 -0.028338
# 2   0.004197 -0.050762  0.046158 -0.064829 -0.080029  0.029207 -0.039758
# 3   0.033775 -0.041534 -0.055019  0.025898 -0.037772 -0.045355 -0.012629
# 4   0.085399  0.016501 -0.091871 -0.073075  0.028603 -0.029270 -0.051421
# 5   0.004027 -0.035185  0.009875 -0.041686 -0.005549 -0.000823  0.021647
# 6  -0.095510  0.100117 -0.067980 -0.027027 -0.056321 -0.043631  0.012542
# 7  -0.047961 -0.003757 -0.004641  0.033482  0.006443 -0.074332  0.000488
# 8   0.281516  0.276046  0.297702  0.211459  0.198787  0.211561  0.282886
# 9  -0.043867 -0.017675  0.011824  0.037742  0.004698  0.065470  0.066613
# 10  0.474394  0.370133  0.369055  0.359249  0.363375  0.332962  0.352278
# 11       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# ...
