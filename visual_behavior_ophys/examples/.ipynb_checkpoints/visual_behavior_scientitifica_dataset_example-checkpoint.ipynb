# %%
import os
import numpy as np
import pandas as pd
import h5py 

import matplotlib.pyplot as plt
# %matplotlib inline
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
ophys_session_dir = r"\\allen\programs\braintv\production\neuralcoding\prod0\specimen_589751232\ophys_session_616633696"

# %%
analysis_dir = r'\\allen\programs\braintv\workgroups\nc-ophys\BehaviorImaging\DoC\2P6_data_analysis'

# %%
mouse_id = 324022

# %%
from visual_behavior_ophys.dataset.visual_behavior_scientifica_dataset import VisualBehaviorScientificaDataset

# %%
dataset= VisualBehaviorScientificaDataset(ophys_session_dir, mouse_id, analysis_dir = analysis_dir)
# Out:
# Visual frames detected in sync: 216874
# 2P frames detected in sync: 111708
# 170905
# visual frames in pkl file: 215788
# Loading \\allen\programs\braintv\workgroups\neuralcoding\Behavior\Data\M324022\output\170905113300-task=DoC_NaturalImages_Ophys_SessionC_stage=natural_images_ophys_session_C_mouse=M324022.pkl
# stim type is  images
# filter edge cells = True
# length of traces: 111624
# number of segmented cells: 154

# %% [markdown]
# #stimulus analysis object
# interlength
# get_noise_correlation
# get_peak
# get_response
# get_representational_similarity
# get_signal_correlation
# get_sweep_response
# get_mean_sweep_response
# plotting functions

# %%
from visual_behavior_ophys.response_analysis.response_analysis import ResponseAnalysis

# %%
ra = ResponseAnalysis(dataset)
# Out:
# length of traces: 111624
# number of segmented cells: 154
# generating response dataframe
# saving response dataframe
# done

# %%
rdf = ra.get_response_dataframe()
dataset.response_df = rdf
# Out:
# loading response dataframe
# done

# %%
rdf.head()
# Out:
#    cell  trial           response response_timestamps  response_window_mean  \
# 0     0      0  [0.0587058745623]          [70.26667]                   NaN
# 1     1      0  [-0.044882976905]          [70.26667]                   NaN
# 2     2      0              [nan]          [70.26667]                   NaN
# 3     3      0   [0.152316676282]          [70.26667]                   NaN
# 4     4      0  [-0.108642292981]          [70.26667]                   NaN
#
#    baseline_window_mean  p_value  sd_over_baseline  \
# 0                   NaN      NaN               NaN
# 1                   NaN      NaN               NaN
# 2                   NaN      NaN               NaN
# 3                   NaN      NaN               NaN
# 4                   NaN      NaN               NaN
#
#                                            run_speed  \
# 0  [-0.0369518164149, -0.0566705528562, -0.074921...
# 1  [-0.0369518164149, -0.0566705528562, -0.074921...
# 2  [-0.0369518164149, -0.0566705528562, -0.074921...
# 3  [-0.0369518164149, -0.0566705528562, -0.074921...
# 4  [-0.0369518164149, -0.0566705528562, -0.074921...
#
#                                       run_timestamps           ...             \
# 0  [11.00715, 11.02386, 11.04054, 11.05723, 11.07...           ...
# 1  [11.00715, 11.02386, 11.04054, 11.05723, 11.07...           ...
# 2  [11.00715, 11.02386, 11.04054, 11.05723, 11.07...           ...
# 3  [11.00715, 11.02386, 11.04054, 11.05723, 11.07...           ...
# 4  [11.00715, 11.02386, 11.04054, 11.05723, 11.07...           ...
#
#    total_trial  change_frame change_time  initial_code  change_code  \
# 0            6           899    15.01045             6            5
# 1            6           899    15.01045             6            5
# 2            6           899    15.01045             6            5
# 3            6           899    15.01045             6            5
# 4            6           899    15.01045             6            5
#
#    initial_image  change_image  trial_type  behavioral_response  \
# 0          im075         im073          go                  1.0
# 1          im075         im073          go                  1.0
# 2          im075         im073          go                  1.0
# 3          im075         im073          go                  1.0
# 4          im075         im073          go                  1.0
#
#   behavioral_response_type
# 0                      HIT
# 1                      HIT
# 2                      HIT
# 3                      HIT
# 4                      HIT
#
# [5 rows x 24 columns]

# %%
from visual_behavior_ophys.plotting_tools import summary_figures as sf

# %%
sf.plot_behavior_events_trace(dataset, range(dataset.dff_traces.shape[0]), xmin=360, length=6, ax=None, save=True)

# %%
sf.plot_traces_heatmap(dataset, save=True, cbar=True, ax=None)

# %%
from visual_behavior_ophys.plotting_tools import basic_plotting as bp

# %%
for roi in range(dataset.dff_traces.shape[0]):
    figsize=(20, 5)
    fig,ax = plt.subplots(figsize=figsize)
    bp.plot_trace(dataset.dff_traces[roi], ylabel='dF/F', interval=5, ax=ax)
    sf.save_figure(fig, figsize, dataset.analysis_dir, 'dff_traces', 'roi_'+str(roi), formats=['.png'])
    plt.close()
