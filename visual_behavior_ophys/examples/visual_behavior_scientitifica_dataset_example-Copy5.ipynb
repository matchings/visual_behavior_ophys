# %%
import os
import numpy as np
import pandas as pd
import h5py 

import matplotlib.pyplot as plt
# %matplotlib inline
# %load_ext autoreload

# %%
ophys_session_dir = r"\\allen\programs\braintv\production\neuralcoding\prod0\specimen_594684843\ophys_session_616863512"

# %%
analysis_dir = r'\\allen\programs\braintv\workgroups\nc-ophys\BehaviorImaging\DoC\2P6_data_analysis'

# %%
mouse_id = 328341

# %%
from visual_behavior_ophys.dataset.visual_behavior_scientifica_dataset import VisualBehaviorScientificaDataset

# %%
dataset = VisualBehaviorScientificaDataset(ophys_session_dir, mouse_id, analysis_dir = analysis_dir)
# Out:
# Visual frames detected in sync: 215791
# 2P frames detected in sync: 111614
# 170906
# visual frames in pkl file: 215791
# Loading \\allen\programs\braintv\workgroups\neuralcoding\Behavior\Data\M328341\output\170906135057-task=DoC_NaturalImages_Ophys_SessionE_stage=natural_images_ophys_session_E_mouse=M328341.pkl
# stim type is  images
# c:\users\marinag\documents\code\visual_behavior_ophys\visual_behavior_ophys\dataset\visual_behavior_scientifica_dataset.py:189: FutureWarning: pd.rolling_mean is deprecated for ndarrays and will be removed in a future version
#   running_speed_cm_per_sec = pd.rolling_mean(running_speed_cm_per_sec, window=6)
# filter edge cells = True
# length of traces: 111608
# number of segmented cells: 91

# %%
dataset.sync_data.plot_lines(['2p_vsync'],start_time=100,end_time=500)

# %%
dataset.sync_data.plot_lines(['2p_trigger'],start_time=100,end_time=500)

# %%
dataset.sync['trigger']['timestamps'][0]
# Out:
# 264.56889999999999

# %%
dataset.sync['2PFrames']['timestamps'][dataset.sync['2PFrames']['timestamps']<dataset.sync['trigger']['timestamps'][0]]
# Out:
# (0L,)

# %%
dataset.sync
# Out:
# {'2PFrames': {'timestamps': array([  196.33507,   196.36737,   196.39966, ...,  3874.60989,
#           3874.64221,  3874.67454])},
#  'cam1_exposure': {'timestamps': array([  5.55780000e-01,   5.92870000e-01,   6.01860000e-01, ...,
#            3.87551136e+03,   3.87554747e+03,   3.87557881e+03])},
#  'cam2_exposure': {'timestamps': array([  4.90080000e-01,   5.13300000e-01,   5.24180000e-01, ...,
#            3.87490192e+03,   3.87493814e+03,   3.87496985e+03])},
#  'lickTimes_0': {'timestamps': array([  268.06126,   268.30154,   275.16776, ...,  3873.09028,
#           3873.24192,  3873.57737])},
#  'stim_photodiode': {'timestamps': array([  275.62294,   277.62457,   279.6262 , ...,  3869.02561,
#           3871.02725,  3873.02889])},
#  'trigger': {'timestamps': array([ 264.5689])},
#  'visualFrames': {'timestamps': array([  274.59872,   274.61532,   274.632  , ...,  3874.47343,
#           3874.49007,  3874.50672])}}

# %%
112772-111620
# Out:
# 1152

# %%
from visual_behavior_ophys.response_analysis.response_analysis import ResponseAnalysis

# %%
ra = ResponseAnalysis(dataset)
# Out:
# length of traces: 111620
# number of segmented cells: 60
# loading response dataframe
# done

# %%
plt.plot(dataset.running_speed)
plt.xlim(150000,160000)
# Out:
# (150000, 160000)

# %%
112588-111620
# Out:
# 968

# %%
# rdf = ra.get_response_dataframe()
# dataset.response_df = rdf

# %%
ra.response_df.head()
# Out:
#    cell  trial                                           response  \
# 0     0      0  [-0.0207669759138, 0.0282864904508, -0.0757592...
# 1     1      0  [-0.0131672122177, -0.022176349383, -0.0084311...
# 2     2      0  [0.105554138495, 0.0813975843235, 0.0616140526...
# 3     3      0  [0.0501915369284, 0.0271260400481, -0.00915645...
# 4     4      0  [-0.0587120545998, -0.0563299663761, 0.1540204...
#
#                                  response_timestamps  response_window_mean  \
# 0  [238.33456, 238.36685, 238.39915, 238.43145, 2...              0.018191
# 1  [238.33456, 238.36685, 238.39915, 238.43145, 2...             -0.002247
# 2  [238.33456, 238.36685, 238.39915, 238.43145, 2...             -0.001541
# 3  [238.33456, 238.36685, 238.39915, 238.43145, 2...             -0.006211
# 4  [238.33456, 238.36685, 238.39915, 238.43145, 2...             -0.012083
#
#    baseline_window_mean   p_value  sd_over_baseline  \
# 0             -0.018531  0.032894          0.429429
# 1             -0.012354  0.381088         -0.067867
# 2              0.017198  0.231099         -0.034674
# 3              0.006843  0.442534         -0.161570
# 4             -0.042258  0.197919         -0.167594
#
#                                            run_speed  \
# 0  [nan, nan, nan, nan, nan, 10.0562054754, 10.05...
# 1  [nan, nan, nan, nan, nan, 10.0562054754, 10.05...
# 2  [nan, nan, nan, nan, nan, 10.0562054754, 10.05...
# 3  [nan, nan, nan, nan, nan, 10.0562054754, 10.05...
# 4  [nan, nan, nan, nan, nan, 10.0562054754, 10.05...
#
#                                       run_timestamps           ...             \
# 0  [238.57329, 238.58987, 238.60656, 238.62325, 2...           ...
# 1  [238.57329, 238.58987, 238.60656, 238.62325, 2...           ...
# 2  [238.57329, 238.58987, 238.60656, 238.62325, 2...           ...
# 3  [238.57329, 238.58987, 238.60656, 238.62325, 2...           ...
# 4  [238.57329, 238.58987, 238.60656, 238.62325, 2...           ...
#
#    total_trial  change_frame change_time  initial_code  change_code  \
# 0            0           225   242.32604             2            0
# 1            0           225   242.32604             2            0
# 2            0           225   242.32604             2            0
# 3            0           225   242.32604             2            0
# 4            0           225   242.32604             2            0
#
#     initial_image    change_image  trial_type  behavioral_response  \
# 0  img063_VH.tiff  img061_VH.tiff          go                  1.0
# 1  img063_VH.tiff  img061_VH.tiff          go                  1.0
# 2  img063_VH.tiff  img061_VH.tiff          go                  1.0
# 3  img063_VH.tiff  img061_VH.tiff          go                  1.0
# 4  img063_VH.tiff  img061_VH.tiff          go                  1.0
#
#   behavioral_response_type
# 0                      HIT
# 1                      HIT
# 2                      HIT
# 3                      HIT
# 4                      HIT
#
# [5 rows x 24 columns]

# %%
from visual_behavior_ophys.plotting_tools import summary_figures as sf

# %%
sf.plot_behavior_events_trace(dataset, range(dataset.dff_traces.shape[0]), xmin=1500, length=10, ax=None, save=True)

# %%
sf.plot_traces_heatmap(dataset, save=True, cbar=True, ax=None)

# %%
from visual_behavior_ophys.plotting_tools import basic_plotting as bp

# %%
for roi in range(dataset.dff_traces.shape[0]):
    figsize=(20, 5)
    fig,ax = plt.subplots(figsize=figsize)
    bp.plot_trace(dataset.dff_traces[roi], ylabel='dF/F', interval=5, ax=ax)
    sf.save_figure(fig, figsize, dataset.analysis_dir, 'dff_traces', 'roi_'+str(roi), formats=['.png'])
    plt.close()
